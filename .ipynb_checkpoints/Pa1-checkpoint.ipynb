# %%
import sklearn as sk
import pandas as pd
import numpy as np
import seaborn as sns
import csv
import matplotlib.pyplot as plt

# %%
X_train = pd.read＿csv('X_train.csv')
y_train = pd.read_csv('y_train.csv')
X_test = pd.read_csv('X_test.csv')

#X_train = pd.read＿csv('train_selected_x.csv')
#X_test = pd.read_csv('test_selected_x.csv')

# %%
#把訓練資料的TF欄位改成01

from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()

X_train_names = X_train.columns

for X_train_name in X_train_names:
    A = X_train[ "%s" % (X_train_name)][0]
    #print( X_train[ "%s" % (X_train_name)][0] )
    if isinstance(A, str):
        X_train[ "%s" % (X_train_name)] = labelencoder.fit_transform(X_train[ "%s" % (X_train_name)])
        #X_train = X_train.drop(X_train_name, axis = 1)

# %%
#把測試資料的TF欄位改成01

X_test_names = X_test.columns

for X_test_name in X_test_names:
    A = X_test[ "%s" % (X_test_name)][0]
    #print( X_train[ "%s" % (X_train_name)][0] )
    if isinstance(A, str):
        X_test[ "%s" % (X_test_name)] = labelencoder.fit_transform(X_test[ "%s" % (X_test_name)])
        #X_test = X_test.drop(X_test_name, axis = 1)

# %%
Y_train = list(y_train['月租金'])

# %%
#合併Y_train
X_train.insert(42,column="月租金", value=y_train)

# %%
# 定義判別欄位型態的函數
def Col_Types( Data ):
    Column_Types = Data.dtypes.to_frame().reset_index()   # 判別每個欄位的型態 
    Column_Types.columns = ['ColumnName','Type']
    Column_Types.sort_values( by='Type', inplace=True ) 
    return Column_Types

# %%
display( Col_Types(X_train) )
# Out:
#     ColumnName     Type
# 0           縣市    int64
# 23      有性別限制？    int64
# 24        性別限制    int64
# 25         可炊？    int64
# 26         可寵？    int64
# 27      有產權登記？    int64
# 28       刊登者類型    int64
# 29     提供家具_床？    int64
# 30    提供家具_桌子？    int64
# 22      有身份限制？    int64
# 31    提供家具_椅子？    int64
# 33   提供家具_熱水器？    int64
# 34    提供家具_冷氣？    int64
# 35    提供家具_沙發？    int64
# 36   提供家具_洗衣機？    int64
# 37    提供家具_衣櫃？    int64
# 38    提供家具_冰箱？    int64
# 39    提供家具_網路？    int64
# 40   提供家具_第四台？    int64
# 32    提供家具_電視？    int64
# 41  提供家具_天然瓦斯？    int64
# 21   額外費用_第四台？    int64
# 19    額外費用_瓦斯？    int64
# 1         鄉鎮市區    int64
# 2     最大出租所費天數    int64
# 3       需要管理費？    int64
# 4         月管理費    int64
# 5        提供車位？    int64
# 6       需要停車費？    int64
# 7         建築類型    int64
# 8         物件類型    int64
# 20    額外費用_網路？    int64
# 9         所在樓層    int64
# 11       距頂樓層數    int64
# 13         陽台數    int64
# 14         衛浴數    int64
# 15          房數    int64
# 16         客廳數    int64
# 17    額外費用_電費？    int64
# 18    額外費用_水費？    int64
# 10        建物樓高    int64
# 42         月租金    int64
# 12          坪數  float64

# %%
#資料描述
display(X_train.describe())
# Out:
#                鄉鎮市區      最大出租所費天數        需要管理費？          月管理費    提供車位？  \
# count  49967.000000  49967.000000  49967.000000  49967.000000  49967.0
# mean    1538.243060     12.312606      0.553926   1697.441772      0.0
# std      305.309465      8.375244      0.497088   2344.562903      0.0
# min        3.000000      1.000000      0.000000      0.000000      0.0
# 25%     1400.000000      5.000000      0.000000      0.000000      0.0
# 50%     1602.000000     10.000000      1.000000   1500.000000      0.0
# 75%     1625.000000     18.000000      1.000000   2666.000000      0.0
# max     2537.000000     98.000000      1.000000  50000.000000      0.0
#
#              需要停車費？          建築類型          物件類型          所在樓層          建物樓高  \
# count  49967.000000  49967.000000  49967.000000  49967.000000  49967.000000
# mean       0.288250      1.877319      0.000600      7.717934     14.120119
# std        0.452953      0.384578      0.024496      5.412797      6.241137
# min        0.000000      0.000000      0.000000     -3.000000      1.000000
# 25%        0.000000      2.000000      0.000000      3.000000     11.000000
# 50%        0.000000      2.000000      0.000000      7.000000     14.000000
# 75%        1.000000      2.000000      0.000000     11.000000     15.000000
# max        1.000000      2.000000      1.000000     35.000000     68.000000
#
#        ...      提供家具_沙發？     提供家具_洗衣機？      提供家具_衣櫃？      提供家具_冰箱？  \
# count  ...  49967.000000  49967.000000  49967.000000  49967.000000
# mean   ...      0.667861      0.678208      0.724738      0.684912
# std    ...      0.470985      0.467169      0.446651      0.464556
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      1.000000      1.000000      1.000000      1.000000
# 75%    ...      1.000000      1.000000      1.000000      1.000000
# max    ...      1.000000      1.000000      1.000000      1.000000
#
#            提供家具_網路？     提供家具_第四台？    提供家具_天然瓦斯？            月租金          縣市分類  \
# count  49967.000000  49967.000000  49967.000000   49967.000000  49967.000000
# mean       0.073108      0.062361      0.795545   31357.070266      2.709808
# std        0.260317      0.241813      0.403307   21574.612597      0.624427
# min        0.000000      0.000000      0.000000    1350.000000      1.000000
# 25%        0.000000      0.000000      1.000000   22000.000000      3.000000
# 50%        0.000000      0.000000      1.000000   26000.000000      3.000000
# 75%        0.000000      0.000000      1.000000   33000.000000      3.000000
# max        1.000000      1.000000      1.000000  400000.000000      3.000000
#
#                衛浴分類
# count  49662.000000
# mean       1.763662
# std        0.729431
# min        1.000000
# 25%        1.000000
# 50%        2.000000
# 75%        2.000000
# max        5.000000
#
# [8 rows x 42 columns]

# %%
# 租金 與其他欄位間的相關係數
Corr_Matrix = X_train.corr()  # 計算相關係數
Corr = Corr_Matrix.loc['月租金',:].sort_values()[:-1]
Corr = pd.DataFrame({ '月租金':Corr })
Corr
# Out:
#                  月租金
# 縣市分類       -0.472115
# 需要停車費？     -0.048780
# 提供家具_網路？   -0.040286
# 提供家具_第四台？  -0.034022
# 物件類型       -0.020465
# 提供家具_床？    -0.014875
# 可寵？        -0.008780
# 有性別限制？     -0.006410
# 性別限制       -0.005849
# 提供家具_沙發？    0.001683
# 提供家具_熱水器？   0.006629
# 額外費用_電費？    0.006828
# 提供家具_椅子？    0.010698
# 提供家具_桌子？    0.010698
# 額外費用_瓦斯？    0.015075
# 提供家具_洗衣機？   0.016633
# 有身份限制？      0.020714
# 提供家具_電視？    0.021478
# 提供家具_冰箱？    0.022582
# 提供家具_冷氣？    0.028206
# 建築類型        0.031796
# 可炊？         0.037556
# 額外費用_第四台？   0.046360
# 額外費用_網路？    0.049958
# 額外費用_水費？    0.051150
# 提供家具_衣櫃？    0.057019
# 有產權登記？      0.058491
# 所在樓層        0.058940
# 鄉鎮市區        0.064933
# 縣市          0.067657
# 需要管理費？      0.077071
# 距頂樓層數       0.080916
# 提供家具_天然瓦斯？  0.101327
# 刊登者類型       0.101698
# 最大出租所費天數    0.114579
# 建物樓高        0.116212
# 最大出租天數分類    0.117383
# 陽台分類        0.180318
# 客廳數         0.184215
# 陽台數         0.185956
# 房數          0.269619
# 衛浴數         0.338070
# 衛浴分類        0.348875
# 坪數          0.575037
# 月管理費        0.585416
# 月租金         1.000000

# %%
#檢視資料內容
plt.scatter("月租金", "最大出租所費天數", data=X_train, alpha = 0.2)
plt.xlabel('Rent')
plt.ylabel('Day')
plt.show()

# %%
#挑掉錯誤、極值
X_train = X_train.drop(X_train[X_train['月租金']>400000].index)

# %%
#建立最大出租天數的新類別
X_train['最大出租天數分類'] = np.nan
X_train.loc[X_train.最大出租所費天數<6,'最大出租天數分類']=1
X_train.loc[(X_train.最大出租所費天數>=6) & (X_train.最大出租所費天數<11) ,'最大出租天數分類']=2
X_train.loc[(X_train.最大出租所費天數>=11) & (X_train.最大出租所費天數<16) ,'最大出租天數分類']=3
X_train.loc[(X_train.最大出租所費天數>=16) & (X_train.最大出租所費天數<21) ,'最大出租天數分類']=4
X_train.loc[(X_train.最大出租所費天數>=21) & (X_train.最大出租所費天數<26) ,'最大出租天數分類']=5
X_train.loc[(X_train.最大出租所費天數>=26) & (X_train.最大出租所費天數<31) ,'最大出租天數分類']=6
X_train.loc[(X_train.最大出租所費天數>=31) ,'最大出租天數分類']=7

# %%
#檢視資料內容
X_test['物件類型'].value_counts()
# Out:
# 0    9990
# 1       9
# 2       1
# Name: 物件類型, dtype: int64

# %%
#挑掉錯誤、極值
X_train = X_train.drop(X_train[X_train['物件類型']>1].index)

# %%
#檢視資料內容
X_train.縣市.value_counts()
# Out:
# 16    20384
# 14     9106
# 11     5313
# 17     4599
# 13     3211
# 25     2196
# 18     2134
# 12     1900
# 21      460
# 8       116
# 9       112
# 10      108
# 7       100
# 5        63
# 0        51
# 24       50
# 6        43
# 20       41
# 19        9
# 23        3
# Name: 縣市, dtype: int64

# %%
#挑掉錯誤、極值
X_train = X_train.drop(X_train[X_train['縣市']==15].index)

# %%
#建立縣市的新類別
X_train['縣市分類'] = np.nan
X_train.loc[X_train.縣市==17,'縣市分類']=1
X_train.loc[X_train.縣市==11,'縣市分類']=2
X_train.loc[(X_train.縣市!=17) & (X_train.縣市!=11) ,'縣市分類']=3

# %%
#檢視資料內容
X_train.衛浴數.value_counts()
# Out:
# 2    27150
# 1    18084
# 3     2977
# 4      990
# 5      315
# 0      305
# 6      126
# 7       20
# 8        4
# 9        1
# Name: 衛浴數, dtype: int64

# %%
#建立衛浴的新類別
X_train['衛浴分類'] = np.nan
X_train.loc[X_train.衛浴數==1,'衛浴分類']=1
X_train.loc[X_train.衛浴數==2,'衛浴分類']=2
X_train.loc[(X_train.衛浴數==3) ,'衛浴分類']=3
X_train.loc[X_train.衛浴數==4,'衛浴分類']=4
X_train.loc[X_train.衛浴數>4,'衛浴分類']=5

# %%
#檢視資料內容
X_train.月管理費.value_counts()
# Out:
# 0       22300
# 2000     4535
# 3000     3540
# 2500     1695
# 1500      708
#         ...
# 3577        1
# 1843        1
# 5461        1
# 3057        1
# 9019        1
# Name: 月管理費, Length: 3138, dtype: int64

# %%
#挑掉錯誤、極值
X_train = X_train.drop(X_train[X_train['月管理費']>X_train['月租金']].index)

# %%
#檢視資料內容
X_train.所在樓層.value_counts()
# Out:
#  3     4388
#  4     3857
#  5     3711
#  6     3504
#  2     3480
#  0     3279
#  7     3254
#  8     3225
#  9     3183
#  10    2681
#  11    2575
#  12    2444
#  13    1938
#  14    1754
#  15    1499
#  1     1403
#  16     603
#  17     550
#  18     499
#  19     394
#  20     392
#  22     310
#  21     270
#  23     181
#  24     165
#  25     112
#  26      97
#  27      94
#  28      45
#  29      42
#  33      13
# -1       13
#  30      11
#  35       4
#  31       3
# -3        3
# -2        2
#  32       1
# Name: 所在樓層, dtype: int64

# %%
#挑掉錯誤、極值
X_train = X_train.drop(X_train[X_train['所在樓層']>35].index)
X_train = X_train.drop(X_train[X_train['所在樓層']<(-6)].index)

# %%
#檢視資料內容
X_train.陽台數.value_counts()
# Out:
# 1     23536
# 2     19838
# 0      3207
# 3      2334
# 4       686
# 5       228
# 6       121
# 7        16
# 11        5
# 9         2
# 14        1
# 8         1
# 10        1
# Name: 陽台數, dtype: int64

# %%
#挑掉錯誤、極值
X_train = X_train.drop(X_train[X_train['陽台數']>20].index)

# %%
#建立陽台新類別
X_train['陽台分類'] = np.nan
X_train.loc[X_train.陽台數==0,'陽台分類']=1
X_train.loc[X_train.陽台數==1,'陽台分類']=2
X_train.loc[(X_train.陽台數==2) ,'陽台分類']=3
X_train.loc[X_train.陽台數==3,'陽台分類']=4
X_train.loc[X_train.陽台數>3,'陽台分類']=5

# %%
#FeatureSelection
#Droplist = ['性別限制','有性別限制？','縣市','陽台分類','最大出租天數分類']
X_train = X_train.drop('最大出租天數分類' , axis=1)

SelectedFeature = list(X_train.columns)
SelectedFeature.remove('月租金')
SelectedFeature
# Out:
# ['鄉鎮市區',
#  '最大出租所費天數',
#  '需要管理費？',
#  '月管理費',
#  '提供車位？',
#  '需要停車費？',
#  '建築類型',
#  '物件類型',
#  '所在樓層',
#  '建物樓高',
#  '距頂樓層數',
#  '坪數',
#  '陽台數',
#  '衛浴數',
#  '房數',
#  '客廳數',
#  '額外費用_電費？',
#  '額外費用_水費？',
#  '額外費用_瓦斯？',
#  '額外費用_網路？',
#  '額外費用_第四台？',
#  '有身份限制？',
#  '可炊？',
#  '可寵？',
#  '有產權登記？',
#  '刊登者類型',
#  '提供家具_床？',
#  '提供家具_桌子？',
#  '提供家具_椅子？',
#  '提供家具_電視？',
#  '提供家具_熱水器？',
#  '提供家具_冷氣？',
#  '提供家具_沙發？',
#  '提供家具_洗衣機？',
#  '提供家具_衣櫃？',
#  '提供家具_冰箱？',
#  '提供家具_網路？',
#  '提供家具_第四台？',
#  '提供家具_天然瓦斯？',
#  '縣市分類',
#  '衛浴分類']

# %%
#訓練
from sklearn.ensemble import RandomForestRegressor

# 建立 Random Forest Regressor 模型
RF = RandomForestRegressor(n_estimators=300, max_depth=40, min_samples_leaf = 1, random_state=1)
# 使用訓練資料訓練模型
RF.fit( X_train[SelectedFeature], X_train.月租金)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 7
#       5 RF = RandomForestRegressor(n_estimators=300, max_depth=40, min_samples_leaf = 1, random_state=1)
#       6 # 使用訓練資料訓練模型
# ----> 7 RF.fit( X_train[SelectedFeature], X_train.月租金)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/ensemble/_forest.py:345, in BaseForest.fit(self, X, y, sample_weight)
#     343 if issparse(y):
#     344     raise ValueError("sparse multilabel-indicator for y is not supported.")
# --> 345 X, y = self._validate_data(
#     346     X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     347 )
#     348 if sample_weight is not None:
#     349     sample_weight = _check_sample_weight(sample_weight, X)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/base.py:565, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     563         y = check_array(y, input_name="y", **check_y_params)
#     564     else:
# --> 565         X, y = check_X_y(X, y, **check_params)
#     566     out = X, y
#     568 if not no_val_X and check_params.get("ensure_2d", True):
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:1106, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1101         estimator_name = _check_estimator_name(estimator)
#    1102     raise ValueError(
#    1103         f"{estimator_name} requires y to be passed, but the target y is None"
#    1104     )
# -> 1106 X = check_array(
#    1107     X,
#    1108     accept_sparse=accept_sparse,
#    1109     accept_large_sparse=accept_large_sparse,
#    1110     dtype=dtype,
#    1111     order=order,
#    1112     copy=copy,
#    1113     force_all_finite=force_all_finite,
#    1114     ensure_2d=ensure_2d,
#    1115     allow_nd=allow_nd,
#    1116     ensure_min_samples=ensure_min_samples,
#    1117     ensure_min_features=ensure_min_features,
#    1118     estimator=estimator,
#    1119     input_name="X",
#    1120 )
#    1122 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1124 check_consistent_length(X, y)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:921, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     915         raise ValueError(
#     916             "Found array with dim %d. %s expected <= 2."
#     917             % (array.ndim, estimator_name)
#     918         )
#     920     if force_all_finite:
# --> 921         _assert_all_finite(
#     922             array,
#     923             input_name=input_name,
#     924             estimator_name=estimator_name,
#     925             allow_nan=force_all_finite == "allow-nan",
#     926         )
#     928 if ensure_min_samples > 0:
#     929     n_samples = _num_samples(array)
#
# File ~/anaconda3/lib/python3.10/site-packages/sklearn/utils/validation.py:161, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     144 if estimator_name and input_name == "X" and has_nan_error:
#     145     # Improve the error message on how to handle missing values in
#     146     # scikit-learn.
#     147     msg_err += (
#     148         f"\n{estimator_name} does not accept missing values"
#     149         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     159         "#estimators-that-handle-nan-values"
#     160     )
# --> 161 raise ValueError(msg_err)
#
# ValueError: Input X contains NaN.
# RandomForestRegressor does not accept missing values encoded as NaN natively. For supervised learning, you might want to consider sklearn.ensemble.HistGradientBoostingClassifier and Regressor which accept missing values encoded as NaNs natively. Alternatively, it is possible to preprocess the data, for instance by using an imputer transformer in a pipeline or drop samples with missing values. See https://scikit-learn.org/stable/modules/impute.html You can find a list of all estimators that handle NaN values at the following page: https://scikit-learn.org/stable/modules/impute.html#estimators-that-handle-nan-values

# %%
# 沒有標準化的預測成功的比例
print("訓練集:" , RF.score(X_train[SelectedFeature],X_train.月租金))
# Out:
# 訓練集: 0.9723274885107518

# %% [markdown]
# ### record
# 什麼都沒做, 300,40 0.97188942

# %%
predicted = RF.predict(X_test[SelectedFeature])

# %%
# 整理預測結果資料格式
predicted = pd.DataFrame(predicted)
predicted.index = predicted.index +1
predicted.insert(0, column="INDEX", value=predicted.index)
predicted.columns=['INDEX', 'RENT']

# %%
predicted.to_csv("R11725045_李名涵_RF300403.csv", index = False)

# %%
# 資料標準化
from sklearn import preprocessing
#建立MinMaxScaler物件
minmax = preprocessing.MinMaxScaler()
# 資料標準化
X_train2 = minmax.fit_transform(X_train)

# %%
X_test2 = minmax.fit_transform(X_test)

# %%
# 建立 Random Forest Regressor 模型
from sklearn.ensemble import RandomForestRegressor
RF2 = RandomForestRegressor(n_estimators=300, max_depth=40, min_samples_leaf = 1, random_state=1)
# 使用標準化後的訓練資料訓練模型
RF2.fit( X_train2, Y_train)
# Out:
# RandomForestRegressor(max_depth=40, n_estimators=300, random_state=1)

# %%
# 標準化的預測成功的比例
print("訓練集:" , RF2.score(X_train2,Y_train))
# Out:
# 訓練集: 0.9724871619783346
